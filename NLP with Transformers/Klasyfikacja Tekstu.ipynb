# %%
from huggingface_hub import list_datasets

all_datasets = list(list_datasets())
print(f"There are {len(all_datasets)} datasets on the hub")
print(f"The first 10 are {all_datasets[:10]}")
# Out:
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 1s [Retry 1/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 2s [Retry 2/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 4s [Retry 3/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 4/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 5/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 6/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 7/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 8/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 9/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 10/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 11/20].
# HTTP Error 429 thrown while requesting GET https://huggingface.co/api/datasets?sort=trendingScore&cursor=eyIkb3IiOlt7InRyZW5kaW5nU2NvcmUiOjAsIl9pZCI6eyIkZ3QiOiI2OGNmMDUxZGFlMGNlZDYxZjhkOWY2YTcifX0seyJ0cmVuZGluZ1Njb3JlIjp7IiRsdCI6MH19LHsidHJlbmRpbmdTY29yZSI6bnVsbH1dfQ%3D%3D
# Retrying in 8s [Retry 12/20].
# There are 538384 datasets on the hub
# The first 10 are [DatasetInfo(id='nvidia/PhysicalAI-Autonomous-Vehicles', author='nvidia', sha='0c8e5b7813562ab6e907e55db6ead3351922073f', created_at=datetime.datetime(2025, 5, 27, 16, 29, 36, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2025, 10, 28, 20, 31, 51, tzinfo=datetime.timezone.utc), private=False, gated='auto', disabled=False, downloads=2507, downloads_all_time=None, likes=129, paperswithcode_id=None, tags=['license:other', 'region:us'], trending_score=129, card_data=None, siblings=None), DatasetInfo(id='HuggingFaceFW/finewiki', author='HuggingFaceFW', sha='8bd13e72e6a002407649b3e898535f42ceb1aeb9', created_at=datetime.datetime(2025, 10, 13, 12, 22, 30, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2025, 10, 22, 11, 2, 22, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=11168, downloads_all_time=None, likes=186, paperswithcode_id=None, tags=['task_categories:text-generation', 'license:cc-by-sa-4.0', 'license:gfdl', 'size_categories:10M<n<100M', 'format:parquet', 'modality:tabular', 'modality:text', 'library:datasets', 'library:dask', 'library:mlcroissant', 'library:polars', 'region:us'], trending_score=82, card_data=None, siblings=None), DatasetInfo(id='neulab/agent-data-collection', author='neulab', sha='be642a9410da2dbba67ae1f476beb41059487c83', created_at=datetime.datetime(2025, 6, 20, 15, 56, 26, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2025, 9, 9, 22, 4, 42, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=3374, downloads_all_time=None, likes=42, paperswithcode_id=None, tags=['task_categories:text-generation', 'language:en', 'size_categories:100K<n<1M', 'modality:text', 'region:us'], trending_score=39, card_data=None, siblings=None), DatasetInfo(id='nvidia/Nemotron-VLM-Dataset-v2', author='nvidia', sha='fca8efa9c6efa1df1e23e5598bfb48d24b203ed4', created_at=datetime.datetime(2025, 10, 13, 12, 54, 46, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2025, 10, 30, 13, 41, 39, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=1409, downloads_all_time=None, likes=33, paperswithcode_id=None, tags=['task_categories:visual-question-answering', 'task_categories:image-text-to-text', 'task_categories:video-text-to-text', 'license:cc-by-4.0', 'size_categories:1M<n<10M', 'format:json', 'modality:text', 'library:datasets', 'library:pandas', 'library:mlcroissant', 'library:polars', 'region:us'], trending_score=33, card_data=None, siblings=None), DatasetInfo(id='AlicanKiraz0/Turkish-SFT-Dataset-v1.0', author='AlicanKiraz0', sha='5a5a852ab9067866d72ed92381205518feaae5fb', created_at=datetime.datetime(2025, 10, 25, 19, 21, 29, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2025, 10, 26, 17, 22, 53, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=593, downloads_all_time=None, likes=33, paperswithcode_id=None, tags=['task_categories:text-classification', 'task_categories:question-answering', 'task_categories:text-generation', 'language:tr', 'license:mit', 'size_categories:1K<n<10K', 'format:json', 'modality:text', 'library:datasets', 'library:pandas', 'library:mlcroissant', 'library:polars', 'region:us', 'turkish'], trending_score=33, card_data=None, siblings=None), DatasetInfo(id='HuggingFaceM4/FineVision', author='HuggingFaceM4', sha='3c380a731a3429c1d04693d6ec16d7e683def84c', created_at=datetime.datetime(2025, 7, 28, 16, 12, 38, tzinfo=datetime.timezone.utc), last_modified=datetime.datetime(2025, 10, 21, 10, 12, 56, tzinfo=datetime.timezone.utc), private=False, gated=False, disabled=False, downloads=250343, downloads_all_time=None, likes=426, paperswithcode_id=None, tags=['size_categories:10M<n<100M', 'format:parquet', 'modality:image', 'modality:text', 'library:datasets', 'library:dask', 'library:mlcroissant', 'library:polars', 'arxiv:2510.17269', 'region:us'], trending_score=26, card_data=None, sib ...

# %%
from datasets import load_dataset
emotions = load_dataset("emotion")

# %%
emotions
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 16000
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 2000
#     })
# })
